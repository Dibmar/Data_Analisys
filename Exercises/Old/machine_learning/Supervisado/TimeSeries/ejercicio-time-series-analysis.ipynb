# %% [markdown]
# <center>
# <img src="https://habrastorage.org/files/fd4/502/43d/fd450243dd604b81b9713213a247aa20.jpg">
# ## [mlcourse.ai](https://mlcourse.ai) – Open Machine Learning Course
# <center>Author: [Mariya Mansurova](https://www.linkedin.com/in/mariya-mansurova-04070982/), analyst & developer in Yandex.Metrics team. <br>Translated by [Ivan Zakharov](https://www.linkedin.com/in/ivan-zakharov/), ML enthusiast.
# <br>All content is distributed under the [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/) license.

# %% [markdown]
# # <center> Assignment #9 (demo)
# ## <center> Time series analysis
#
# **Fill cells marked with "Your code here" and submit your answers to the questions through the [web form](https://docs.google.com/forms/d/1UYQ_WYSpsV3VSlZAzhSN_YXmyjV7YlTP8EYMg8M8SoM/edit).**

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import os

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly import graph_objs as go
import requests
import pandas as pd

from sklearn.metrics import mean_absolute_error

import statsmodels.formula.api as smf            # statistics and econometrics
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

print(__version__) # need 1.9.0 or greater
init_notebook_mode(connected = True)


def plotly_df(df, title = ''):
    data = []
    
    for column in df.columns:
        trace = go.Scatter(
            x = df.index,
            y = df[column],
            mode = 'lines',
            name = column
        )
        data.append(trace)
    
    layout = dict(title = title)
    fig = dict(data = data, layout = layout)
    iplot(fig, show_link=False)
# Out:
# 4.8.1
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Data preparation

# %%
df = pd.read_csv(r'F:\Programacion\1.BOOTCAMP\data\general_dfs\wiki_machine_learning.csv', sep = ' ')
df = df[df['count'] != 0]
df.head()
# Out:
#           date  count lang              page  rank   month             title
# 81  2015-01-01   1414   en  Machine_learning  8708  201501  Machine_learning
# 80  2015-01-02   1920   en  Machine_learning  8708  201501  Machine_learning
# 79  2015-01-03   1338   en  Machine_learning  8708  201501  Machine_learning
# 78  2015-01-04   1404   en  Machine_learning  8708  201501  Machine_learning
# 77  2015-01-05   2264   en  Machine_learning  8708  201501  Machine_learning

# %%
df.shape
# Out:
# (383, 7)

# %% [markdown]
# ## Predicting with FB Prophet
# We will train at first 5 months and predict the number of trips for June.

# %%
df.date = pd.to_datetime(df.date)

# %%
plotly_df(df.set_index('date')[['count']])
# Out:
# <div>
#
#
#             <div id="f14a125d-1eb6-4c57-ba88-0462ed325db4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f14a125d-1eb6-4c57-ba88-0462ed325db4")) {
#                     Plotly.newPlot(
#                         'f14a125d-1eb6-4c57-ba88-0462ed325db4',
#                         [{"mode": "lines", "name": "count", "type": "scatter", "x": ["2015-01-01T00:00:00", "2015-01-02T00:00:00", "2015-01-03T00:00:00", "2015-01-04T00:00:00", "2015-01-05T00:00:00", "2015-01-06T00:00:00", "2015-01-07T00:00:00", "2015-01-08T00:00:00", "2015-01-09T00:00:00", "2015-01-10T00:00:00", "2015-01-11T00:00:00", "2015-01-12T00:00:00", "2015-01-13T00:00:00", "2015-01-14T00:00:00", "2015-01-15T00:00:00", "2015-01-16T00:00:00", "2015-01-17T00:00:00", "2015-01-18T00:00:00", "2015-01-19T00:00:00", "2015-01-20T00:00:00", "2015-01-21T00:00:00", "2015-01-22T00:00:00", "2015-01-23T00:00:00", "2015-01-24T00:00:00", "2015-01-25T00:00:00", "2015-01-26T00:00:00", "2015-01-27T00:00:00", "2015-01-28T00:00:00", "2015-01-29T00:00:00", "2015-01-30T00:00:00", "2015-01-31T00:00:00", "2015-02-01T00:00:00", "2015-02-02T00:00:00", "2015-02-03T00:00:00", "2015-02-04T00:00:00", "2015-02-06T00:00:00", "2015-02-07T00:00:00", "2015-02-08T00:00:00", "2015-02-09T00:00:00", "2015-02-10T00:00:00", "2015-02-11T00:00:00", "2015-02-12T00:00:00", "2015-02-13T00:00:00", "2015-02-14T00:00:00", "2015-02-15T00:00:00", "2015-02-16T00:00:00", "2015-02-17T00:00:00", "2015-02-18T00:00:00", "2015-02-19T00:00:00", "2015-02-20T00:00:00", "2015-02-21T00:00:00", "2015-02-22T00:00:00", "2015-02-23T00:00:00", "2015-02-24T00:00:00", "2015-02-25T00:00:00", "2015-02-26T00:00:00", "2015-02-27T00:00:00", "2015-02-28T00:00:00", "2015-03-01T00:00:00", "2015-03-02T00:00:00", "2015-03-03T00:00:00", "2015-03-04T00:00:00", "2015-03-05T00:00:00", "2015
df.columns = ['ds', 'y']
df.tail()
# Out:
#             ds     y
# 382 2016-01-16  1644
# 381 2016-01-17  1836
# 376 2016-01-18  2983
# 375 2016-01-19  3389
# 372 2016-01-20  3559

# %% [markdown]
# **<font color='red'>Question 1:</font>** What is the prediction of the number of views of the wiki page on January 20? Round to the nearest integer.
#
# - 4947
# - 3426
# - 5229
# - 2744

# %%
# You code here
def moving_average(series, n):
    """
        Calculate average of last n observations
    """
    return np.average(series[-20:])

mov_av = moving_average(df.y, predictions)
mov_av
# Out:
# 2623.7

# %% [markdown]
# Estimate the quality of the prediction with the last 30 points.

# %%
def _error(actual: np.ndarray, predicted: np.ndarray):
    """ Simple error """
    return actual - predicted
def mae(actual: np.ndarray, predicted: np.ndarray):
    """ Mean Absolute Error """
    return np.mean(np.abs(_error(actual, predicted)))

# %%
_error(df.y[:-1], mov_av)
mae = round(mae(df.y[:-1], mov_av), 0)
mae
# Out:
# 552.0

# %%
mape = mae/100
mape
# Out:
# 5.52

# %% [markdown]
# **<font color='red'>Question 2:</font> What is MAPE equal to?**
#
# - 34.5
# - 42.42
# - 5.39
# - 65.91
#
# **<font color='red'>Question 3:</font> What is MAE equal to?**
#
# - 355
# - 4007
# - 600
# - 903

# %% [markdown]
# ## Predicting with ARIMA

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
plt.rcParams['figure.figsize'] = (15, 10)

# %% [markdown]
# **<font color='red'>Question 4:</font> Let's verify the stationarity of the series using the Dickey-Fuller test. Is the series stationary? What is the p-value?**
#
# - Series is stationary, p_value = 0.107
# - Series is not stationary, p_value = 0.107
# - Series is stationary, p_value = 0.001
# - Series is not stationary, p_value = 0.001

# %%
from statsmodels.tsa.stattools import adfuller
adfTest = adfuller(df.y, autolag='AIC')
adfTest [1]
# Out:
# 0.015383668419468997

# %% [markdown]
# **Next, we turn to the construction of the SARIMAX model (`sm.tsa.statespace.SARIMAX`).<br> <font color='red'>Question 5:</font> What parameters are the best for the model according to the `AIC` criterion?**
#
# - D = 1, d = 0, Q = 0, q = 2, P = 3, p = 1
# - D = 2, d = 1, Q = 1, q = 2, P = 3, p = 1
# - D = 1, d = 1, Q = 1, q = 2, P = 3, p = 1
# - D = 0, d = 0, Q = 0, q = 2, P = 3, p = 1

# %%
# You code here
D = [1, 2, 1, 0]
d = [0, 1, 1, 0]
Q = [0, 1, 1, 0]
q = 2
P = 3
p = 1
s = 19

# %%
for e in range(len(D)):
    best_model = sm.tsa.statespace.SARIMAX(df.y, order=(p, d[e], q), seasonal_order=(P, D[e], Q[e], s)).fit(disp=-1)
    print(best_model.summary())
# Out:
# F:\Programacion\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning:
#
# An unsupported index was provided and will be ignored when e.g. forecasting.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-918c81e55cf3> in <module>
#       1 for e in range(len(D)):
# ----> 2     best_model = sm.tsa.statespace.SARIMAX(df.y, order=(p, d[e], q), seasonal_order=(P, D[e], Q[e], s)).fit(disp=-1)
#       3     print(best_model.summary())
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     488         else:
#     489             res = self.smooth(mlefit.params, transformed=False,
# --> 490                               cov_type=cov_type, cov_kwds=cov_kwds)
#     491
#     492             res.mlefit = mlefit
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     609         return self._wrap_results(params, result, return_ssm, cov_type,
#     610                                   cov_kwds, results_class,
# --> 611                                   results_wrapper_class)
#     612
#     613     _loglike_param_names = ['transformed', 'complex_step']
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _wrap_results(self, params, result, return_raw, cov_type, cov_kwds, results_class, wrapper_class)
#     515                 wrapper_class = self._res_classes['fit'][1]
#     516
# --> 517             res = results_class(self, params, result, **result_kwargs)
#     518             result = wrapper_class(res)
#     519         return result
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in __init__(self, model, params, filter_results, cov_type, **kwargs)
#    1692                  **kwargs):
#    1693         super(SARIMAXResults, self).__init__(model, params, filter_results,
# -> 1694                                              cov_type, **kwargs)
#    1695
#    1696         self.df_resid = np.inf  # attribute required for wald tests
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in __init__(self, model, params, results, cov_type, cov_kwds, **kwargs)
#    1609             self._rank = None
#    1610             self._get_robustcov_results(cov_type=cov_type, use_self=True,
# -> 1611                                         **cov_kwds)
#    1612         except np.linalg.LinAlgError:
#    1613             self._rank = 0
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _get_robustcov_results(self, cov_type, **kwargs)
#    1736                                                 approx_type=approx_type_str)
#    1737         elif self.cov_type == 'opg':
# -> 1738             res.cov_params_default = res.cov_params_opg
#    1739             res.cov_kwds['description'] = descriptions['OPG'].format(
#    1740                                                 approx_type=approx_type_str)
#
# F:\Programacion\lib\site-packages\statsmodels\tools\decorators.py in __get__(self, obj, type)
#      91         _cachedval = _cache.get(name, None)
#      92         if _cachedval is None:
# ---> 93             _cachedval = self.fget(obj)
#      94             _cache[name] = _cachedval
#      95
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in cov_params_opg(self)
#    1836         """
#    1837         return self._cov_params_opg(self._cov_approx_complex_step,
# -> 1838                                     self._cov_approx_centered)
#    1839
#    1840     @cache_readonly
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _cov_params_opg(self, approx_complex_step, approx_centered)
#    1820             self.params, transformed=True,
#    1821             approx_complex_step=approx_complex_step,
# -> 1822             approx_centered=approx_centered)
#    1823
#    1824         (neg_cov, singular_values) = pinv_extended(evaluated_hessian)
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in _hessian_opg(self, params, **kwargs)
#    1239         information matrix
#    1240         """
# -> 1241         return -self.opg_information_matrix(params, **kwargs)
#    1242
#    1243     def _hessian_finite_difference(self, params, approx_centered=False,
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in opg_information_matrix(self, params, transformed, approx_complex_step, **kwargs)
#     942         score_obs = self.score_obs(params, transformed=transformed,
#     943                                    approx_complex_step=approx_complex_step,
# --> 944                                    **kwargs).transpose()
#     945         return (
#     946             np.inner(score_obs, score_obs) /
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in score_obs(self, params, method, transformed, approx_complex_step, approx_centered, **kwargs)
#    1145             kwargs['transformed'] = True
#    1146             score = approx_fprime_cs(params, self.loglikeobs, epsilon=epsilon,
# -> 1147                                      kwargs=kwargs)
#    1148         elif method == 'approx':
#    1149             kwargs['transformed'] = transformed
#
# F:\Programacion\lib\site-packages\statsmodels\tools\numdiff.py in approx_fprime_cs(x, f, epsilon, args, kwargs)
#     200     # TODO: see if this can be vectorized, but usually dim is small
#     201     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
# --> 202                 for i, ih in enumerate(increments)]
#     203     return np.array(partials).T
#     204
#
# F:\Programacion\lib\site-packages\statsmodels\tools\numdiff.py in <listcomp>(.0)
#     200     # TODO: see if this can be vectorized, but usually dim is small
#     201     partials = [f(x+ih, *args, **kwargs).imag / epsilon[i]
# --> 202                 for i, ih in enumerate(increments)]
#     203     return np.array(partials).T
#     204
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglikeobs(self, params, transformed, complex_step, **kwargs)
#     705         self.update(params, transformed=True, complex_step=complex_step)
#     706
# --> 707         return self.ssm.loglikeobs(complex_step=complex_step, **kwargs)
#     708
#     709     def simulation_smoother(self, simulation_output=None, **kwargs):
#
# F:\Programacion\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglikeobs(self, **kwargs)
#     929         if not self.filter_method & FILTER_CONCENTRATED:
#     930             kwargs['conserve_memory'] = MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD
# --> 931         kfilter = self._filter(**kwargs)
#     932         llf_obs = np.array(kfilter.loglikelihood, copy=True)
#     933         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#
# KeyboardInterrupt:
